# %%
base_dir = "/home/mfholth/subseasonal/weekly_data/conformal_UQ/Region_model_results"
from pathlib import Path
import sys
PROJECT_ROOT = Path.cwd().parents[0]
sys.path.append(str(PROJECT_ROOT / "src"))
from conformal.methods.global_cp import run_global_conformal
from conformal.metrics import compare_results
from conformal.plots import plot_interval_grid
from conformal.metrics import *
from conformal.methods.dynamic_graph import run_dynamic_graph_cp
import os

base_dir = "/home/mfholth/subseasonal/weekly_data/conformal_UQ/Region_model_results"

alpha = 0.10
y_true_col = "y_true_kelvin"
y_pred_col = "y_pred_kelvin"
os.path.join
cal_files = {
    1: os.path.join(base_dir, "Calibration_long_1.csv"),
    2: os.path.join(base_dir, "Calibration_long_2.csv"),
    3: os.path.join(base_dir, "Calibration_long_3.csv"),
    4: os.path.join(base_dir, "Calibration_long_4.csv"),
}

test_files = {
    1: os.path.join(base_dir, "Test_long_1.csv"),
    2: os.path.join(base_dir, "Test_long_2.csv"),
    3: os.path.join(base_dir, "Test_long_3.csv"),
    4: os.path.join(base_dir, "Test_long_4.csv"),
}

# %%
import pandas as pd
import os
base_dir = "/home/mfholth/subseasonal/weekly_data/conformal_UQ/Region_model_results"



cal_files = {
    1: os.path.join(base_dir, "Calibration_long_1.csv"),
    2: os.path.join(base_dir, "Calibration_long_2.csv"),
    3: os.path.join(base_dir, "Calibration_long_3.csv"),
    4: os.path.join(base_dir, "Calibration_long_4.csv"),
}

test_files = {
    1: os.path.join(base_dir, "Test_long_1.csv"),
    2: os.path.join(base_dir, "Test_long_2.csv"),
    3: os.path.join(base_dir, "Test_long_3.csv"),
    4: os.path.join(base_dir, "Test_long_4.csv"),
}

test = pd.read_csv(cal_files[4])
test.shape
# Out:
# (995, 152)

# %%
global_result = run_global_conformal(
    cal_files,
    test_files,
    alpha=alpha,
    y_true_col=y_true_col,
    y_pred_col=y_pred_col,
)

# %%
test["y_true_kelvin"]
# Out:
# 0      276.239500
# 1      282.487087
# 2      280.639260
# 3      278.717251
# 4      280.145319
#           ...
# 990    278.132074
# 991    272.812944
# 992    273.382723
# 993    268.156655
# 994    272.491536
# Name: y_true_kelvin, Length: 995, dtype: float64

# %%
global_result.predictions_by_horizon[2].shape
# Out:
# (1005, 191)

# %%
test = global_result.stacked_predictions()
test.head()
# Out:
#    horizon Region      y_true      y_pred       lower       upper  covered  \
# 0        1      W  277.022491  275.453314  272.013024  278.893603     True
# 1        1     MW  276.483600  271.778289  268.337999  275.218578    False
# 2        1     SE  284.568863  283.202979  279.762689  286.643268     True
# 3        1     NE  269.283666  268.464916  265.024627  271.905206     True
# 4        1     SW  283.329087  283.247142  279.806853  286.687432     True
#
#       width  interval_score  forecast_date  reference_date     q_hat  Season  \
# 0  6.880579        6.880579         201707          201706  3.440289  Winter
# 1  6.880579       32.181013         201707          201706  3.440289  Winter
# 2  6.880579        6.880579         201707          201706  3.440289  Winter
# 3  6.880579        6.880579         201707          201706  3.440289  Winter
# 4  6.880579        6.880579         201707          201706  3.440289  Winter
#
#    method
# 0  global
# 1  global
# 2  global
# ...

# %%
test = pd.read_csv(cal_files[4])
test.head()
# Out:
#    current_week     lag_1     lag_2     lag_3     lag_4     lag_5  \
# 0      2.326722 -0.667479 -3.586567 -1.128998 -1.939801 -6.334524
# 1      2.489336  2.326722 -0.667479 -3.586567 -1.128998 -1.939801
# 2     -1.087770  2.489336  2.326722 -0.667479 -3.586567 -1.128998
# 3     -2.215244 -1.087770  2.489336  2.326722 -0.667479 -3.586567
# 4      0.001564 -2.215244 -1.087770  2.489336  2.326722 -0.667479
#
#    h_500_weekave_arctic_pc16  h_500_weekave_arctic_pc18  \
# 0               -1191.932929                -378.199164
# 1                1311.938032                -540.565242
# 2                -606.114793                 412.907057
# 3               -3036.203587               -2105.541546
# 4               -4463.493451                -527.121144
#
#    h_500_weekave_arctic_pc9  h_500_weekave_atlantic_ocean_pc16  ...         y  \
# 0              -2556.014488                        -464.384995  ...  0.001564
# ...

# %%
temp=summarize_result(global_result)
# Out:
# /home/mfholth/subseasonal/weekly_data/conformal_UQ/conformal/metrics.py:30: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tmp = df.groupby(["Region", "Season"], dropna=False).agg(
# /home/mfholth/subseasonal/weekly_data/conformal_UQ/conformal/metrics.py:30: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tmp = df.groupby(["Region", "Season"], dropna=False).agg(
# ...

# %%
import pandas as pd
test = pd.read_csv("/home/mfholth/subseasonal/weekly_data/conformal_UQ/Region_model_results/Test_long_1.csv")
test.shape
# Out:
# (1010, 214)

# %%
temp[temp["group"] == "overall"]
# Out:
#       group group_value  coverage  mean_width  median_width     n  method  \
# 0   overall         all  0.900000    6.880579      6.880579  1010  global
# 26  overall         all  0.899502    7.613306      7.613306  1005  global
# 52  overall         all  0.900000    7.944066      7.944066  1000  global
# 78  overall         all  0.899497    7.969003      7.969003   995  global
#
#     horizon
# 0         1
# 26        2
# 52        3
# 78        4

# %%
temp.head()
# Out:
#      group group_value  coverage  mean_width  median_width     n  method  \
# 0  overall         all  0.900000    6.880579      6.880579  1010  global
# 1   Region          MW  0.851485    6.880579      6.880579   202  global
# 2   Region          NE  0.886139    6.880579      6.880579   202  global
# 3   Region          SE  0.886139    6.880579      6.880579   202  global
# 4   Region          SW  0.970297    6.880579      6.880579   202  global
#
#    horizon
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1

# %%
temp = pd.read_csv("/home/mfholth/subseasonal/weekly_data/conformal_UQ/conformal_code/outputs/tuning/epsilon_tuning/epsilon_tuning_test_exp_1.csv")

# %%
# mark where year changes
temp = pd.read_csv("/home/mfholth/subseasonal/weekly_data/conformal_UQ/conformal_code/outputs/tuning/epsilon_tuning/epsilon_tuning_test_exp_1.csv")
temp.head()
# Out:
#    horizon Region       lower       upper  covered      width  interval_score  \
# 0        1      W  270.064537  280.842091     True  10.777555       10.777555
# 1        1     MW  266.915194  276.641383     True   9.726189        9.726189
# 2        1     SE  278.469649  287.936308     True   9.466659        9.466659
# 3        1     NE  263.759605  273.170227     True   9.410622        9.410622
# 4        1     SW  279.771975  286.722310     True   6.950335        6.950335
#
#    forecast_date  reference_date kernel_kind  tau_weeks  y_true_kelvin  \
# 0         201707          201706         exp          1     277.022491
# 1         201707          201706         exp          1     276.483600
# 2         201707          201706         exp          1     284.568863
# 3         201707          201706         exp          1     269.283666
# 4         201707          201706         exp          1     283.329087
#
#    y_pred_kelvin
# 0     275.453314
# 1     271.778289
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams.update({
"font.size": 14, # base size
"axes.titlesize": 16,
"axes.labelsize": 14,
"xtick.labelsize": 12,
"ytick.labelsize": 12,
"legend.fontsize": 12,
})

# -----------------------------
# user inputs
# -----------------------------
files_by_tau = {
    1: "/home/mfholth/subseasonal/weekly_data/conformal_UQ/conformal_code/outputs/tuning/epsilon_tuning/epsilon_tuning_test_exp_1.csv",
    2: "/home/mfholth/subseasonal/weekly_data/conformal_UQ/conformal_code/outputs/tuning/epsilon_tuning/epsilon_tuning_test_exp_2.csv",
    3: "/home/mfholth/subseasonal/weekly_data/conformal_UQ/conformal_code/outputs/tuning/epsilon_tuning/epsilon_tuning_test_exp_3.csv",
    4: "/home/mfholth/subseasonal/weekly_data/conformal_UQ/conformal_code/outputs/tuning/epsilon_tuning/epsilon_tuning_test_exp_4.csv",
}

region_to_plot = "W"
horizon_to_plot = 1
x_col = "forecast_date"   # or "reference_date"

# -----------------------------
# plotting
# -----------------------------
fig, axes = plt.subplots(4, 1, figsize=(16, 12), sharex=True)

for ax, tau in zip(axes, [1, 2, 3, 4]):
    df = pd.read_csv(files_by_tau[tau])

    # subset to one region + one horizon
    sub = df[(df["Region"] == region_to_plot) & (df["horizon"] == horizon_to_plot)].copy()
    
    # sort by time
    sub = sub.sort_values(x_col).reset_index(drop=True)
    sub["timestep"] = sub.index
    # plot interval
    ax.fill_between(
        sub["timestep"],
        sub["lower"],
        sub["upper"],
        alpha=0.25,
        label="90% PI"
    )

    # plot truth and prediction
    ax.plot(sub["timestep"], sub["y_true_kelvin"], label="Observed", linewidth=1.2)
    ax.plot(sub["timestep"], sub["y_pred_kelvin"], label="Predicted", linewidth=1.2)
    years = sub["forecast_date"] // 100
    year_change_idx = sub.index[years.diff() != 0]
    
    for idx in year_change_idx:
        ax.axvline(idx, linestyle="--", alpha=0.9)

    # optional coverage annotation
    covered = ((sub["y_true_kelvin"] >= sub["lower"]) & (sub["y_true_kelvin"] <= sub["upper"])).mean()
    med_width = (sub["upper"] - sub["lower"]).median()

    ax.set_title(f"tau_weeks = {tau} | coverage = {covered:.3f} | median width = {med_width:.2f}")
    ax.set_ylabel("Temperature (K)")
    ax.grid(alpha=0.3)

axes[-1].set_xlabel(x_col)
handles, labels = axes[0].get_legend_handles_labels()
fig.legend(handles, labels, loc="upper center", ncol=3, frameon=False)
fig.suptitle(f"Prediction intervals by tau | Region = {region_to_plot}, Horizon = {horizon_to_plot}", y=0.98)
fig.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %%
files_by_tau = {
    1: "/home/mfholth/subseasonal/weekly_data/conformal_UQ/conformal_code/outputs/tuning/epsilon_tuning/epsilon_tuning_test_gauss_1.csv",
    2: "/home/mfholth/subseasonal/weekly_data/conformal_UQ/conformal_code/outputs/tuning/epsilon_tuning/epsilon_tuning_test_gauss_2.csv",
    3: "/home/mfholth/subseasonal/weekly_data/conformal_UQ/conformal_code/outputs/tuning/epsilon_tuning/epsilon_tuning_test_gauss_3.csv",
    4: "/home/mfholth/subseasonal/weekly_data/conformal_UQ/conformal_code/outputs/tuning/epsilon_tuning/epsilon_tuning_test_gauss_4.csv",
}

region_to_plot = "W"
horizon_to_plot = 1
x_col = "forecast_date"   # or "reference_date"

# -----------------------------
# plotting
# -----------------------------
fig, axes = plt.subplots(4, 1, figsize=(16, 12), sharex=True)

for ax, tau in zip(axes, [1, 2, 3, 4]):
    df = pd.read_csv(files_by_tau[tau])

    # subset to one region + one horizon
    sub = df[(df["Region"] == region_to_plot) & (df["horizon"] == horizon_to_plot)].copy()
    
    # sort by time
    sub = sub.sort_values(x_col).reset_index(drop=True)
    sub["timestep"] = sub.index
    # plot interval
    ax.fill_between(
        sub["timestep"],
        sub["lower"],
        sub["upper"],
        alpha=0.25,
        label="90% PI"
    )

    # plot truth and prediction
    ax.plot(sub["timestep"], sub["y_true_kelvin"], label="Observed", linewidth=1.2)
    ax.plot(sub["timestep"], sub["y_pred_kelvin"], label="Predicted", linewidth=1.2)
    years = sub["forecast_date"] // 100
    year_change_idx = sub.index[years.diff() != 0]
    
    for idx in year_change_idx:
        ax.axvline(idx, linestyle="--", alpha=0.9)

    # optional coverage annotation
    covered = ((sub["y_true_kelvin"] >= sub["lower"]) & (sub["y_true_kelvin"] <= sub["upper"])).mean()
    med_width = (sub["upper"] - sub["lower"]).median()

    ax.set_title(f"tau_weeks = {tau} | coverage = {covered:.3f} | median width = {med_width:.2f}")
    ax.set_ylabel("Temperature (K)")
    ax.grid(alpha=0.3)

axes[-1].set_xlabel(x_col)
handles, labels = axes[0].get_legend_handles_labels()
fig.legend(handles, labels, loc="upper center", ncol=3, frameon=False)
fig.suptitle(f"Prediction intervals by tau | Region = {region_to_plot}, Horizon = {horizon_to_plot}", y=0.98)
fig.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %%
files_by_tau = {
    1: "/home/mfholth/subseasonal/weekly_data/conformal_UQ/conformal_code/outputs/tuning/epsilon_tuning/epsilon_tuning_results_exp_1.csv",
    2: "/home/mfholth/subseasonal/weekly_data/conformal_UQ/conformal_code/outputs/tuning/epsilon_tuning/epsilon_tuning_results_exp_2.csv",
    3: "/home/mfholth/subseasonal/weekly_data/conformal_UQ/conformal_code/outputs/tuning/epsilon_tuning/epsilon_tuning_results_exp_3.csv",
    4: "/home/mfholth/subseasonal/weekly_data/conformal_UQ/conformal_code/outputs/tuning/epsilon_tuning/epsilon_tuning_results_exp_4.csv",
}

# %%
files_by_tau = {
    1: "/home/mfholth/subseasonal/weekly_data/conformal_UQ/conformal_code/outputs/tuning/epsilon_tuning/epsilon_tuning_results_gauss_1.csv",
    2: "/home/mfholth/subseasonal/weekly_data/conformal_UQ/conformal_code/outputs/tuning/epsilon_tuning/epsilon_tuning_results_gauss_2.csv",
    3: "/home/mfholth/subseasonal/weekly_data/conformal_UQ/conformal_code/outputs/tuning/epsilon_tuning/epsilon_tuning_results_gauss_3.csv",
    4: "/home/mfholth/subseasonal/weekly_data/conformal_UQ/conformal_code/outputs/tuning/epsilon_tuning/epsilon_tuning_results_gauss_4.csv",
}

# %%
import pandas as pd

summary_rows = []

for tau, path in files_by_tau.items():
    df = pd.read_csv(path)

    df["tau_weeks"] = tau
    summary_rows.append(df)

summary_df = pd.concat(summary_rows, ignore_index=True)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

taus = [1,2,3,4]

fig, axes = plt.subplots(1, len(taus), figsize=(4 * len(taus), 4), sharey=True)

if len(taus) == 1:
    axes = [axes]

for ax, tau in zip(axes, taus):
    sub = summary_df[summary_df["tau_weeks"] == tau]

    heat = sub.pivot(index="Horizon", columns="epsilon", values="Objective")

    sns.heatmap(
        heat,
        annot=True,
        fmt=".2f",
        cmap="viridis_r",   # lower score = better
        cbar=(tau == taus[-1]),
        ax=ax,
        
        vmin = summary_df["Objective"].min(),
        vmax = summary_df["Objective"].max()
    )

    ax.set_title(f"Tau: {tau}")
    ax.set_xlabel("Epsilon")
    ax.set_ylabel("Horizon")

fig.suptitle("Objective by Epsilon and Horizon", y=1.02)
plt.tight_layout()
plt.show()

# %%
files_by_tau = {
    1: "/home/mfholth/subseasonal/weekly_data/conformal_UQ/conformal_code/outputs/tuning/epsilon_tuning/epsilon_tuning_test_gauss_1.csv",
    2: "/home/mfholth/subseasonal/weekly_data/conformal_UQ/conformal_code/outputs/tuning/epsilon_tuning/epsilon_tuning_test_gauss_2.csv",
    3: "/home/mfholth/subseasonal/weekly_data/conformal_UQ/conformal_code/outputs/tuning/epsilon_tuning/epsilon_tuning_test_gauss_3.csv",
    4: "/home/mfholth/subseasonal/weekly_data/conformal_UQ/conformal_code/outputs/tuning/epsilon_tuning/epsilon_tuning_test_gauss_4.csv",
}

import pandas as pd

summary_rows = []

for tau, path in files_by_tau.items():
    df = pd.read_csv(path)

    grp = (
        df.groupby(["Region", "horizon"], observed=False)[["interval_score", "covered"]]
          .mean()
          .reset_index()
    )
    grp["tau_weeks"] = tau
    summary_rows.append(grp)

summary_df = pd.concat(summary_rows, ignore_index=True)

# %%
import seaborn as sns

regions = sorted(summary_df["Region"].unique())

fig, axes = plt.subplots(1, len(regions), figsize=(4 * len(regions), 4), sharey=True)

if len(regions) == 1:
    axes = [axes]

for ax, region in zip(axes, regions):
    sub = summary_df[summary_df["Region"] == region]

    heat = sub.pivot(index="horizon", columns="tau_weeks", values="interval_score")

    sns.heatmap(
        heat,
        annot=True,
        fmt=".2f",
        cmap="viridis_r",   # lower score = better
        cbar=(region == regions[-1]),
        ax=ax,
        annot_kws={"size": 12},
        vmin = summary_df["interval_score"].min(),
        vmax = summary_df["interval_score"].max()
    )

    ax.set_title(f"Region: {region}", fontsize=16)
    ax.set_xlabel("tau_weeks", fontsize=14)
    ax.set_ylabel("Horizon", fontsize=14)

fig.suptitle("Mean Interval Score by Region, Horizon, and tau_weeks", y=1.02, fontsize=16)
plt.tight_layout()
plt.show()

# %%
regions = sorted(summary_df["Region"].unique())

fig, axes = plt.subplots(1, len(regions), figsize=(4 * len(regions), 4), sharey=True)

if len(regions) == 1:
    axes = [axes]

for ax, region in zip(axes, regions):
    sub = summary_df[summary_df["Region"] == region]

    heat = sub.pivot(index="horizon", columns="tau_weeks", values="covered")

    sns.heatmap(
        heat,
        annot=True,
        fmt=".2f",
        cmap="viridis_r",   # lower score = better
        cbar=(region == regions[-1]),
        ax=ax,
        
        vmin = summary_df["covered"].min(),
        vmax = summary_df["covered"].max()
    )

    ax.set_title(f"Region: {region}")
    ax.set_xlabel("tau_weeks")
    ax.set_ylabel("Horizon")

fig.suptitle("Mean proportion covered by Region, Horizon, and tau_weeks", y=1.02)
plt.tight_layout()
plt.show()

# %%
base_dir = "/home/mfholth/subseasonal/weekly_data/conformal_UQ/Region_model_results"
from pathlib import Path
import sys
PROJECT_ROOT = Path.cwd().parents[0]
sys.path.append(str(PROJECT_ROOT / "src"))
from conformal.methods.global_cp import run_global_conformal
from conformal.metrics import compare_results
from conformal.plots import plot_interval_grid
from conformal.metrics import *
from conformal.methods.dynamic_graph import run_dynamic_graph_cp
import os

alpha = 0.10
y_true_col = "y_true_kelvin"
y_pred_col = "y_pred_kelvin"
FORECAST_DATE_COL = "forecast_date"
CURRENT_WEEK_COL = "current_week"

cal_files = {
    1: os.path.join(base_dir, "Calibration_long_1.csv"),
    2: os.path.join(base_dir, "Calibration_long_2.csv"),
    3: os.path.join(base_dir, "Calibration_long_3.csv"),
    4: os.path.join(base_dir, "Calibration_long_4.csv"),
}

test_files = {
    1: os.path.join(base_dir, "Test_long_1.csv"),
    2: os.path.join(base_dir, "Test_long_2.csv"),
    3: os.path.join(base_dir, "Test_long_3.csv"),
    4: os.path.join(base_dir, "Test_long_4.csv"),
}

run_dynamic_graph_cp = run_dynamic_graph_cp(
        cal_files,
        test_files,
        week_kernel="exp",
        tau_weeks=2.5,
        y_true_col=y_true_col,
        y_pred_col=y_pred_col,
        alpha=alpha,
        forecast_date_col=FORECAST_DATE_COL,
        current_week_col=CURRENT_WEEK_COL,
        T_window=20,
        graph_method="corr"
    )
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[2], line 33
#      19 cal_files = {
#      20     1: os.path.join(base_dir, "Calibration_long_1.csv"),
#      21     2: os.path.join(base_dir, "Calibration_long_2.csv"),
#      22     3: os.path.join(base_dir, "Calibration_long_3.csv"),
#      23     4: os.path.join(base_dir, "Calibration_long_4.csv"),
#      24 }
#      26 test_files = {
#      27     1: os.path.join(base_dir, "Test_long_1.csv"),
#      28     2: os.path.join(base_dir, "Test_long_2.csv"),
#      29     3: os.path.join(base_dir, "Test_long_3.csv"),
#      30     4: os.path.join(base_dir, "Test_long_4.csv"),
#      31 }
# ---> 33 run_dynamic_graph_cp = run_dynamic_graph_cp(
#      34         cal_files,
#      35         test_files,
#      36         week_kernel="exp",
#      37         tau_weeks=2.5,
#      38         y_true_col=y_true_col,
# ...

# %%
import numpy as np
import pandas as pd
from conformal.methods.method_helpers import add_season, weighted_quantile, circ_week_dist, Pi_shrinkage, kernel_fn, parse_year_week_from_yyyww, n_eff
from conformal.features import Y_PRED_COL, Y_TRUE_COL, ALPHA, FORECAST_DATE_COL, CURRENT_WEEK_COL
from conformal.config import HORIZONS

def build_region_panel(df, value_col="current_week"):
    """
    Build wide matrix:
      rows   = forecast_date (YYYYWW)
      cols   = Region
      values = current_week anomaly
    Assumes one row per region per date.
    """
    wide = (
        df.pivot_table(
            index=FORECAST_DATE_COL,
            columns="Region",
            values=value_col,
            aggfunc="first"
        )
        .sort_index()
    )
    return wide

def compute_dynamic_similarity_matrix(panel_wide, 
                                      current_date,
                                      T_window,
                                      method="corr"):
    """
    panel_wide: wide matrix indexed by forecast_date, columns=Region
    current_date: integer YYYYWW for the test point
    T_window: number of past rows to use, excluding current_date
    method: 'corr' or 'cosine'

    Returns:
      G: DataFrame of region-region similarities, row-normalized
    """
    if current_date not in panel_wide.index:
        raise ValueError(f"current_date {current_date} not found in region panel")

    idx = panel_wide.index.get_loc(current_date)

    # use only past rows, never current or future
    start = max(0, idx - T_window)
    window = panel_wide.iloc[start:idx].copy()

    # if too few rows, fallback later
    if len(window) < max(4, T_window // 3):
        return None

    # fill missing values with column means inside window
    window = window.apply(lambda col: col.fillna(col.mean()), axis=0)

    regions = list(window.columns)

    if method == "corr":
        G = window.corr()
    elif method == "cosine":
        X = window.to_numpy().T  # shape: regions x time
        norms = np.linalg.norm(X, axis=1, keepdims=True)
        norms[norms == 0] = 1.0
        Xn = X / norms
        G = pd.DataFrame(Xn @ Xn.T, index=regions, columns=regions)
    else:
        raise ValueError("method must be 'corr' or 'cosine'")

    # clip negatives to zero
    G = G.clip(lower=0.0)

    # add tiny diagonal stabilization
    for r in G.index:
        G.loc[r, r] = max(G.loc[r, r], 1e-8)

    # row normalize so each row sums to 1
    row_sums = G.sum(axis=1)
    row_sums[row_sums == 0] = 1.0
    G = G.div(row_sums, axis=0)

    return G

# ============================================================
# MAIN METHOD
# ============================================================
def dynamic_graph_conformal(cal_df,
                            test_df, 
                            y_true_col, 
                            y_pred_col, 
                            alpha, 
                            forecast_date_col,
                            current_week_col,
                            T_window=20, 
                            tau_weeks=4.0,
                            graph_method="corr", 
                            week_kernel="exp"):
    """
    Dynamic graph weighted conformal:
      w_j(x*) ∝ g_t(r_j, r*) * k(w_j, w*)
    """

    cal = parse_year_week_from_yyyww(cal_df, forecast_date_col=forecast_date_col)
    test = parse_year_week_from_yyyww(test_df, forecast_date_col=forecast_date_col)

    cal = add_season_from_weeknum(cal)
    test = add_season_from_weeknum(test)

    cal["score"] = (cal[y_true_col] - cal[y_pred_col]).abs()

    # build region panel from ALL available observations up through test period
    # for a real deployment, this should only contain information available up to each time.
    all_df = pd.concat(
        [
            cal[[forecast_date_col, "Region", current_week_col]],
            test[[forecast_date_col, "Region", current_week_col]],
        ],
        ignore_index=True
    ).drop_duplicates(subset=[forecast_date_col, "Region"])

    region_panel = build_region_panel(all_df, value_col=current_week_col)

    # calibration arrays
    cal_scores = cal["score"].to_numpy()
    cal_weeks = cal["week_num"].to_numpy()
    cal_regions = cal["Region"].to_numpy()

    qhat = np.empty(len(test), dtype=float)
    neff = np.empty(len(test), dtype=float)

    # precompute static fallback global quantile
    global_q = float(np.quantile(cal_scores, 1 - alpha))

    # cache graph by test date since many rows share same date
    graph_cache = {}

    for i, row in enumerate(test.itertuples(index=False)):
        test_date = int(getattr(row, forecast_date_col))
        r_star = getattr(row, "Region")
        w_star = int(getattr(row, "week_num"))

        # dynamic graph for this test date
        if test_date not in graph_cache:
            G_t = compute_dynamic_similarity_matrix(
                region_panel,
                current_date=test_date,
                T_window=T_window,
                method=graph_method
            )
            graph_cache[test_date] = G_t
        else:
            G_t = graph_cache[test_date]

        # fallback if insufficient history
        if G_t is None:
            qhat[i] = global_q
            neff[i] = np.nan
            continue

        # region similarity for each calibration point
        # similarity from test region r_star to cal region r_j
        # because G_t is row-normalized, use row r_star
        if r_star not in G_t.index:
            qhat[i] = global_q
            neff[i] = np.nan
            continue
            
        # Long vec of corrs of all rj w/ r_star
        g_vec = np.array([G_t.loc[r_star, rj] if rj in G_t.columns else 0.0 for rj in cal_regions])

        # week similarity
        # d_week is long vec of corrs between weeks in cal and test point week
        d_week = circ_week_dist(cal_weeks, w_star, period=52)
        k_vec = kernel_fn(d_week, tau=tau_weeks, kind=week_kernel)

        # combined weights
        w = g_vec * k_vec
        s = w.sum()

        if s <= 0:
            qhat[i] = global_q
            neff[i] = np.nan
        else:
            qhat[i] = weighted_quantile(cal_scores, w / s, 1 - alpha)
            neff[i] = effective_n(w)

    out = test.copy()
    out["q_hat"] = qhat
    out["n_eff"] = neff

    df_pi = apply_symmetric_intervals(
            out,
            q=out["q_hat"].values,
            y_true_col=y_true_col,
            y_pred_col=y_pred_col,
            q_col_name="q_hat",
    )

    return df_pi

    
def run_dynamic_graph_cp(cal_files,
                         test_files,
                         week_kernel,
                         tau_weeks,
                         y_true_col,
                         y_pred_col, 
                         alpha, 
                         forecast_date_col,
                         current_week_col,
                         T_window, 
                         graph_method
                        ):
    
    predictions_by_horizon = {}
    
    for h in HORIZONS:
        cal_df = pd.read_csv(cal_files[h])
        test_df = pd.read_csv(test_files[h])
    
        out = dynamic_graph_conformal(
            cal_df=cal_df,
            test_df=test_df,
            y_true_col=y_true_col,
            y_pred_col=y_pred_col,
            alpha=alpha,
            forecast_date_col=forecast_date_col,
            current_week_col=current_week_col,
            T_window=T_window,
            tau_weeks=tau_weeks,
            graph_method="corr",   # try "cosine" too
            week_kernel=week_kernel
        )

        overall_cov = float(out["covered"].mean())
        median_width = float(out["width"].median())
        mean_width = float(out["width"].mean())
        median_neff = float(np.nanmedian(out["n_eff"]))
    
        print(f"\n--- Dynamic Graph Conformal | Horizon {h} ---")
        print(f"Overall coverage: {overall_cov:.3f}")
        print(f"Median width: {median_width:.3f}")
        print(f"Mean width: {mean_width:.3f}")
        print(f"Median n_eff: {median_neff:.1f}")
    
        print("\nCoverage by Region:")
        print(out.groupby("Region")["covered"].mean().round(3))
    
        print("\nCoverage by Region x Season:")
        print(
            out.groupby(["Region", "Season"])["covered"]
            .mean()
            .unstack("Season")
            .round(3)
        )

        df_pi = add_interval_score(df=out, alpha=alpha, y_true_col=y_true_col)
        validate_prediction_df(out)

        predictions_by_horizon[h] = df_pi
        metadata_by_horizon[h] = {"kernel_kind": kernel_kind, 
                                  "tau_weeks": tau_weeks
                                 }
    
    return ConformalResult(
        method="dynamic_graph",
        predictions_by_horizon=predictions_by_horizon,
        metadata_by_horizon=metadata_by_horizon,
        config={
            "alpha": alpha,
            "y_true_col": y_true_col,
            "y_pred_col": y_pred_col,
            "date_col": forecast_date_col,
        },
    )
